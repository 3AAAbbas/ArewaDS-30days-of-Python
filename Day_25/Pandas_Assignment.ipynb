# %% [markdown]
# # **Day 25: 30 Days of python programming**

# %% [markdown]
# # Exercises: Day 25
#
# 1. Read the hacker_news.csv file from data directory

# %%
import numpy as np
import pandas as pd
df = pd.read_csv('hacker_news.csv')
print(df)
# Out:
#              id                                              title  \
# 0      12224879                          Interactive Dynamic Video
# 1      11964716  Florida DJs May Face Felony for April Fools' W...
# 2      11919867       Technology ventures: From Idea to Enterprise
# 3      10301696  Note by Note: The Making of Steinway L1037 (2007)
# 4      10482257  Title II kills investment? Comcast and other I...
# ...         ...                                                ...
# 13549  11084357          Simplifying Legalese for the Internet Age
# 13550  10977306  Matz: I cannot accept the CoC for the Ruby com...
# 13551  10731847  Did You Really Agree to That? The Evolution of...
# 13552  10405148                                Thoughts on Haskell
# 13553  11541591  How to Tell the Difference Between a Good Prog...
#
#                                                      url  num_points  \
# 0                http://www.interactivedynamicvideo.com/       386.0
# 1      http://www.thewire.com/entertainment/2013/04/f...         2.0
# 2      https://www.amazon.com/Technology-Ventures-Ent...         3.0
# 3      http://www.nytimes.com/2007/11/07/movies/07ste...         8.0
# 4      http://arstechnica.com/business/2015/10/comcas...        53.0
# ...                                                  ...         ...
# 13549  http://offprint.in/#!/articles/simplifying-leg...        13.0
# 13550    https://bugs.ruby-lang.org/issues/12004#note-95        39.0
# 13551               http://techscience.org/a/2015081102/        99.0
# 13552    http://khanlou.com/2015/10/thoughts-on-haskell/        41.0
# 13553  http://www.inc.com/rahul-varshneya/how-to-tell...         NaN
#
#        num_comments        author        created_at
# 0              52.0      ne0phyte    8/4/2016 11:52
# 1               1.0      vezycash   6/23/2016 22:20
# 2               1.0       hswarna    6/17/2016 0:01
# 3               2.0    walterbell    9/30/2015 4:12
# 4              22.0        Deinos   10/31/2015 9:48
# ...             ...           ...               ...
# 13549           2.0   kiethtalent    2/12/2016 0:02
# 13550          16.0         jp_sc    1/27/2016 0:16
# 13551          24.0        kawera  12/14/2015 16:14
# 13552          49.0  mr_golyadkin  10/17/2015 17:14
# 13553           NaN           NaN               NaN
#
# [13554 rows x 7 columns]

# %% [markdown]
# 2. Get the first five rows

# %%
df.head()
# Out:
#          id                                              title  \
# 0  12224879                          Interactive Dynamic Video
# 1  11964716  Florida DJs May Face Felony for April Fools' W...
# 2  11919867       Technology ventures: From Idea to Enterprise
# 3  10301696  Note by Note: The Making of Steinway L1037 (2007)
# 4  10482257  Title II kills investment? Comcast and other I...
#
#                                                  url  num_points  \
# 0            http://www.interactivedynamicvideo.com/       386.0
# 1  http://www.thewire.com/entertainment/2013/04/f...         2.0
# 2  https://www.amazon.com/Technology-Ventures-Ent...         3.0
# 3  http://www.nytimes.com/2007/11/07/movies/07ste...         8.0
# 4  http://arstechnica.com/business/2015/10/comcas...        53.0
#
#    num_comments      author       created_at
# 0          52.0    ne0phyte   8/4/2016 11:52
# 1           1.0    vezycash  6/23/2016 22:20
# 2           1.0     hswarna   6/17/2016 0:01
# 3           2.0  walterbell   9/30/2015 4:12
# 4          22.0      Deinos  10/31/2015 9:48

# %% [markdown]
# 3. Get the last five rows

# %%
df.tail()
# Out:
#              id                                              title  \
# 13549  11084357          Simplifying Legalese for the Internet Age
# 13550  10977306  Matz: I cannot accept the CoC for the Ruby com...
# 13551  10731847  Did You Really Agree to That? The Evolution of...
# 13552  10405148                                Thoughts on Haskell
# 13553  11541591  How to Tell the Difference Between a Good Prog...
#
#                                                      url  num_points  \
# 13549  http://offprint.in/#!/articles/simplifying-leg...        13.0
# 13550    https://bugs.ruby-lang.org/issues/12004#note-95        39.0
# 13551               http://techscience.org/a/2015081102/        99.0
# 13552    http://khanlou.com/2015/10/thoughts-on-haskell/        41.0
# 13553  http://www.inc.com/rahul-varshneya/how-to-tell...         NaN
#
#        num_comments        author        created_at
# 13549           2.0   kiethtalent    2/12/2016 0:02
# 13550          16.0         jp_sc    1/27/2016 0:16
# 13551          24.0        kawera  12/14/2015 16:14
# 13552          49.0  mr_golyadkin  10/17/2015 17:14
# 13553           NaN           NaN               NaN

# %% [markdown]
# 4. Get the title column as pandas series

# %%
title = df['title']
print(title)
# Out:
# 0                                Interactive Dynamic Video
# 1        Florida DJs May Face Felony for April Fools' W...
# 2             Technology ventures: From Idea to Enterprise
# 3        Note by Note: The Making of Steinway L1037 (2007)
# 4        Title II kills investment? Comcast and other I...
#                                ...
# 13549            Simplifying Legalese for the Internet Age
# 13550    Matz: I cannot accept the CoC for the Ruby com...
# 13551    Did You Really Agree to That? The Evolution of...
# 13552                                  Thoughts on Haskell
# 13553    How to Tell the Difference Between a Good Prog...
# Name: title, Length: 13554, dtype: object

# %% [markdown]
# 5. Count the number of rows and columns

# %%
df.shape
# Out:
# (13554, 7)

# %% [markdown]
# - Filter the titles which contain python

# %%
df[df['title'].str.lower().str.contains('python')]
# Out:
#              id                                              title  \
# 102    10974870                From Python to Lua: Why We Switched
# 103    11244541          Ubuntu 16.04 LTS to Ship Without Python 2
# 144    10963528  Create a GUI Application Using Qt and Python i...
# 196    10716331  How I Solved GCHQ's Xmas Card with Python and ...
# 436    11895088  Unikernel Power Comes to Java, Node.js, Go, an...
# ...         ...                                                ...
# 12467  11368693      Show HN: Pycraft  learn Python with Minecraft
# 12532  10782969                       'New' Python modules of 2015
# 13126  10522148                       Recreational Maths in Python
# 13218  12095313  DQN for Beginners in 200 lines of python code ...
# 13328  11026148             Building Powerful Frameworks in Python
#
#                                                      url  num_points  \
# 102    https://www.distelli.com/blog/using-lua-for-ou...       243.0
# 103    http://news.softpedia.com/news/ubuntu-16-04-lt...         2.0
# 144                        http://digitalpeer.com/s/c63e        21.0
# 196    http://matthewearl.github.io/2015/12/10/gchq-x...         6.0
# 436    http://www.infoworld.com/article/3082051/open-...         3.0
# ...                                                  ...         ...
# 12467                                                NaN         3.0
# 12532  http://blog.rtwilson.com/my-top-5-new-python-m...       591.0
# 13126  http://www.alanzucconi.com/2015/11/03/recreati...        36.0
# 13218  https://yanpanlau.github.io/2016/07/10/FlappyB...         5.0
# 13328            http://migrateup.com/python-frameworks/         2.0
#
#        num_comments        author        created_at
# 102           188.0      chase202   1/26/2016 18:17
# 103             1.0       _snydly    3/8/2016 10:39
# 144             1.0        zoodle   1/24/2016 19:01
# 196             1.0          kipi  12/11/2015 10:38
# 436             1.0  syslandscape   6/13/2016 16:23
# ...             ...           ...               ...
# 12467           1.0         emeth    3/27/2016 3:15
# 12532         131.0   ColinWright  12/23/2015 12:16
# 13126           4.0         nkurz   11/6/2015 21:25
# 13218           1.0     yanpanlau   7/14/2016 16:40
# 13328           1.0     CarolineW    2/3/2016 12:46
#
# [103 rows x 7 columns]

# %% [markdown]
# - Filter the titles which contain JavaScript

# %%
df[df['title'].str.lower().str.contains('javascript')]
# Out:
#              id                                              title  \
# 267    12352636   Show HN: Hire JavaScript - Top JavaScript Talent
# 580    10871330  Python integration for the Duktape Javascript ...
# 811    10741251  Ask HN: Are there any projects or compilers wh...
# 1046   11343334  If you write JavaScript tools or libraries, bu...
# 1093   10422726  Rollup.js: A next-generation JavaScript module...
# ...         ...                                                ...
# 13327  11150444                              Samson and JavaScript
# 13351  11001820  Furnish JavaScript - Let the classes on DOM el...
# 13368  11416591      Type conversions from JavaScript to C++ in V8
# 13481  11440150  Simple Programs to Learn JavaScript Design Pat...
# 13533  10199605     SQLite compiled into JavaScript via Emscripten
#
#                                                      url  num_points  \
# 267                              https://www.hirejs.com/         1.0
# 580               https://pypi.python.org/pypi/pyduktape         3.0
# 811                                                  NaN         1.0
# 1046   https://medium.com/@Rich_Harris/how-to-not-bre...        48.0
# 1093                                 http://rollupjs.org        57.0
# ...                                                  ...         ...
# 13327  https://medium.com/p/samson-and-javascript-3ff...         2.0
# 13351                https://github.com/Idnan/furnish-js        30.0
# 13368  http://blog.scottfrees.com/type-conversions-fr...        50.0
# 13481       https://github.com/nnupoor/js_designpatterns        20.0
# 13533                  https://github.com/kripken/sql.js       199.0
#
#        num_comments         author        created_at
# 267             1.0       eibrahim   8/24/2016 15:16
# 580             1.0        stefano    1/9/2016 14:26
# 811             2.0        ggonweb  12/15/2015 23:26
# 1046           19.0    callumlocke   3/23/2016 10:54
# 1093           17.0        dmmalam   10/21/2015 0:02
# ...             ...            ...               ...
# 13327           1.0        horrido   2/22/2016 12:51
# 13351          29.0  kamranahmedse   1/30/2016 14:03
# 13368          11.0          ingve    4/3/2016 16:17
# 13481           3.0        verloop    4/6/2016 17:16
# 13533          55.0        sea6ear   9/10/2015 18:14
#
# [125 rows x 7 columns]

# %% [markdown]
# - Explore the data and make sense of it

# %% [markdown]
# ### Info

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 13554 entries, 0 to 13553
# Data columns (total 7 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   id            13554 non-null  int64
#  1   title         13554 non-null  object
#  2   url           11892 non-null  object
#  3   num_points    13553 non-null  float64
#  4   num_comments  13553 non-null  float64
#  5   author        13553 non-null  object
#  6   created_at    13553 non-null  object
# dtypes: float64(2), int64(1), object(4)
# memory usage: 741.4+ KB

# %% [markdown]
# ### Describe

# %%
df.describe()
# Out:
#                  id    num_points  num_comments
# count  1.355400e+04  13553.000000  13553.000000
# mean   1.131987e+07     50.044713     24.560171
# std    6.982333e+05    109.011595     56.367757
# min    1.017692e+07      1.000000      1.000000
# 25%    1.070318e+07      3.000000      1.000000
# 50%    1.128670e+07      9.000000      3.000000
# 75%    1.193408e+07     54.000000     21.000000
# max    1.257898e+07   2553.000000   1733.000000

# %% [markdown]
# ### Author

# %%
df['author'].value_counts()
# Out:
# ingve           138
# prostoalex       85
# dnetesn          66
# jseliger         58
# jonbaer          57
#                ...
# krisives          1
# mikx007           1
# sarciszewski      1
# TylerJewell       1
# jp_sc             1
# Name: author, Length: 7719, dtype: int64
